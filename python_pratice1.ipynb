# %% [markdown]
# <a href="https://colab.research.google.com/github/saratsethy11/python/blob/main/python_pratice1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def fib(n):
  fib_sequence=[0,1]
  for i in range(2,n):
    fib_sequence.append(fib_sequence[i-1]+fib_sequence[i-2])
  return fib_sequence

num_terms = int(input("enter the number of terms:"))
print(fib(num_terms))
# Out:
# enter the number of terms:5
# [0, 1, 1, 2, 3]

# %% [markdown]
# check if the number is positive, negative or zero

# %%
input_user=int(input("enter the number:"))
if input_user>0:
  print("the number is positive")
elif input_user<0:
  print("the number is negative")
else:
  print("the number is zero")
# Out:
# enter the number:5
# the number is positive

# %% [markdown]
# check even and odd

# %%
user_input=int(input("enter the number:"))
if user_input % 2 == 0:
  print("the number is even")
else:
  print("the number is odd")
# Out:
# enter the number:5
# the number is odd

# %% [markdown]
# find the largest of two number

# %%
input_user1=int(input("enter the first number:"))
input_user2=int(input("enter the second number:"))
if input_user1>input_user2:
    print("first number is greater than second number")
else:
    print("second number is greater than first number")
# Out:
# enter the first number:10
# enter the second number:2
# first number is greater than second number

# %% [markdown]
# check voting eligibility

# %%
user=int(input("enter the age:"))
if user>=18:
  print("you are eligible to vote")
else:
  print("you are not eligible to vote")
# Out:
# enter the age:19
# you are eligible to vote

# %% [markdown]
# leap year

# %%
input_year=int(input("enter the year:"))
if ((input_year % 4 == 0 and input_year % 100 != 0) or (input_year % 400 == 0) ):
  print("the year is a leap year")
else:
  print("the year is not a leap year")
# Out:
# enter the year:2020
# the year is a leap year
